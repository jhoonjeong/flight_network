# %%
N_airport = 50
N_edge = 250
N_p = 100

# %%
reward_point, net_model = mc(30000, n_airport=N_airport, n_edges=N_edge, passengers=N_p)

# %%
print(min(reward_point), max(reward_point))
fig = plt.figure(figsize=(16, 6))

ax1 = fig.add_subplot(121)
im1 = ax1.imshow(net_model[np.argmin(reward_point)])

fig.colorbar(im1, ax=ax1, orientation='vertical')
ax1.set_aspect('auto')

ax2 = fig.add_subplot(122)
im2 = ax2.imshow(net_model[np.argmax(reward_point)])

fig.colorbar(im2, ax=ax2, orientation='vertical')
ax2.set_aspect('auto')
# Out:
# -2068.9920290549603 -1083.0216814583384

# %%
net_min = net_model[np.argmin(reward_point)]
net_max = net_model[np.argmax(reward_point)]

v_min = np.min([net_min, net_max])
v_max = np.max([net_min, net_max])

fig = plt.figure(figsize=(16, 6))

ax1 = fig.add_subplot(121)
im1 = ax1.imshow(route_sort(net_min), vmin=v_min, vmax=v_max)

fig.colorbar(im1, ax=ax1, orientation='vertical')
ax1.set_aspect('auto')

ax2 = fig.add_subplot(122)
im2 = ax2.imshow(route_sort(net_max), vmin=v_min, vmax=v_max)

fig.colorbar(im2, ax=ax2, orientation='vertical')
ax2.set_aspect('auto')

# %%
net_min = net_model[np.argmin(reward_point)]
net_max = net_model[np.argmax(reward_point)]

v_min = np.min([net_min, net_max])
v_max = np.max([net_min, net_max])

fig = plt.figure(figsize=(16, 6))

ax1 = fig.add_subplot(121)
im1 = ax1.imshow(np.sort(np.sort(net_min, axis=0)), vmin=v_min, vmax=v_max)

fig.colorbar(im1, ax=ax1, orientation='vertical')
ax1.set_aspect('auto')

ax2 = fig.add_subplot(122)
im2 = ax2.imshow(np.sort(np.sort(net_max, axis=0)), vmin=v_min, vmax=v_max)

fig.colorbar(im2, ax=ax2, orientation='vertical')
ax2.set_aspect('auto')

# %%
sorted_net = route_sort(net_max)
start_point, end_point = net_to_list(sorted_net)
show(chord(N_airport, start_point, end_point, alpha=0.2))
# Out:
#   <div class="bk-root" id="bf62acf7-56c8-48f2-b603-e5a6a077d393"></div>

# %%
sorted_net = route_sort(net_min)
start_point, end_point = net_to_list(sorted_net)
show(chord(N_airport, start_point, end_point, alpha=0.2))
# Out:
#   <div class="bk-root" id="f547086b-c60a-4e1a-966c-446d8756f2c9"></div>
